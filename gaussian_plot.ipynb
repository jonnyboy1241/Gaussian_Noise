# %%
import gaussian_noise
import numpy as np

# %%
x_values, y_values = gaussian_noise.generate_data(0, 10, 50, 5)

# %%
x_values
# Out:
# array([9.01331704, 0.56573237, 4.34000057, 7.81041827, 0.38451877,
#        1.09053997, 0.02553958, 6.37208131, 0.38702084, 1.77982251,
#        8.813284  , 9.31878902, 1.99983772, 5.42855981, 2.06848546,
#        5.10866102, 1.02605182, 8.56266048, 0.94837488, 5.35650228,
#        0.6936893 , 8.84933695, 6.07320564, 2.88028495, 3.60559017,
#        2.47543765, 1.12351802, 0.83120599, 5.23203978, 1.99802396,
#        7.91111521, 7.90541067, 3.14230712, 5.56224892, 3.0771269 ,
#        4.9073726 , 0.01412535, 5.67410048, 9.46409256, 7.58830787,
#        6.48713093, 7.44060204, 6.22192352, 1.30344339, 4.37558267,
#        8.66858468, 5.81696376, 5.57054975, 3.18777221, 3.0319017 ])

# %%
y_values
# Out:
# array([27.58627774,  0.88736137,  8.69617822, 19.28630747,  9.65442168,
#        -0.52531795,  4.87824455, 15.46127329,  3.09693163,  5.28222633,
#        34.01573423, 28.18462906,  2.63397334, 18.3519674 ,  8.48635649,
#        11.22364877, -0.27523219, 27.97557502,  3.32054969, 21.57343305,
#        12.93815755, 25.88504675, 14.63039801,  3.64622505,  4.79542191,
#        12.50097409, -4.39039892, -6.26953289, 10.00424938,  3.00061313,
#        16.21979208, 21.43863965,  9.87624789, 13.66623901,  2.6226877 ,
#        14.02371704, -1.51783004,  9.9251763 , 25.95216783, 17.10297625,
#        21.54548694, 26.40704929, 19.24370594,  1.76357935, 14.87472836,
#        25.69005637, 17.77299873, 25.5530513 , 17.18889777, 13.48808119])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_values, y_values, s=50, facecolors='none', edgecolors='b')
x_cont = np.arange(-2.0, 12.0, .01)
plt.plot(x_cont, 3*x_cont, 'k')
plt.axis([-2, 12, -5, 35])
plt.show()
